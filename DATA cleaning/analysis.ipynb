# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('HARYAN_WHEAT_GURUGRAM.csv')
df
# Out:
#         State District        Market Commodity Variety Grade Arrival_Date  \
# 0     Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   02/05/2008
# 1     Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   05/05/2008
# 2     Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   14/05/2008
# 3     Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   08/07/2008
# 4     Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   16/01/2015
# 5     Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   09/02/2015
# 6     Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   28/03/2015
# 7     Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   10/09/2015
# 8     Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   17/09/2015
# 9     Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   09/11/2015
# 10    Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   01/12/2015
# 11    Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   01/01/2016
# ...

# %%
df1 = df[(df['District'] == 'Gurgaon') & (df['Market'] == 'Farukh Nagar') & (df['Arrival_Date'] > '2022-01-01') & (df['Modal_Price'] > 1500.00)]
df1
# Out:
#        State District        Market Commodity Variety Grade Arrival_Date  \
# 19   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   29/07/2017
# 21   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   27/01/2018
# 23   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   27/03/2022
# 24   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   22/04/2022
# 26   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   26/05/2022
# 28   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   28/04/2023
# 29   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   27/04/2024
# 33   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   22/12/2016
# 34   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   24/12/2016
# 48   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   22/03/2018
# 54   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   26/04/2022
# 62   Haryana  Gurgaon  Farukh Nagar     Wheat   Other   FAQ   25/04/2024
# ...

# %%
df1.plot.scatter(x='Min_Price',y='Max_Price',s=100,c='pink')
# Out:
# <Axes: xlabel='Min_Price', ylabel='Max_Price'>
